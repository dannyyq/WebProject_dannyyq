# %% [markdown]
# ## Creating a Web Data Project with Jupyter Notebooks
# ******
# ###### 1. Read in json file(s) resulting from your work with requests/selenium and beautifulsoup

# %%
# Import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# Read in json files and create dataframes
filename = '2017-03-16.SDNewsBriefs.json'
data = pd.read_json(filename)
filename2 = '2017-03-14.SDNewsBriefs.json'
data2 = pd.read_json(filename2)

# %% [markdown]
# ###### 2. Clean the data column by column
# - Ensure that addresses (or other text data) are consistent
# - Eliminate string characters from numeric values
# - Exclude redundant data as appropriate

# %%
data
# Out:
#                                             Extra Info  \
# 0                                          Terms Apply
# 1                                      + Free Shipping
# 2                                      + Free Shipping
# 3                            1% Cashback (Terms Apply)
# 4                                 (New Customers Only)
# 5                                      + Free Shipping
# 6                          with $5K Spent in 1st 3-mos
# 7                          with $5K Spent in 1st 3-mos
# 8                         + Free Shipping and Handling
# 9                                      + Free Shipping
# 10                        More Options + Free Shipping
# 11                    More Options + Free Store Pickup
# 12                or Less + Free Shipping and Handling
# 13                                     + Free Shipping
# 14                                     + Free Shipping
# 15                                     + Free Shipping
# 16                         with $5K Spent in 1st 3-mos
# 17                         after $50 Slickdeals Rebate
# 18                           1% Cashback (Terms Apply)
# 19                           1% Cashback (Terms Apply)
# 20                                         Terms Apply
# 21                         with $4K Spent in 1st 3-Mos
# 22                                     + Free Shipping
# 23                + Free Shipping and Handling on $75+
# 24           More Options + Free Shipping and Handling
# 25                        + Free Shipping and Handling
# 26                                        with AutoPay
# 27                                       with Auto Pay
# 28   + Free Shipping and Handling (VZW Customers Only)
# 29                                 + Free Store Pickup
# ..                                                 ...
# 153                                       More Options
# 154                   More Options + Free Store Pickup
# 155                                + Free Store Pickup
# 156                                   (Travel Apr-Dec)
# 157                                   (Travel Sep-Nov)
# 158                                + Free Store Pickup
# 159                                    + Free Shipping
# 160                       More Options + Free Shipping
# 161                       More Options + Free Shipping
# 162                       More Options + Free Shipping
# 163                       More Options + Free Shipping
# 164                                    + Free Shipping
# 165                                + Free Store Pickup
# 166                                + Free Store Pickup
# 167                                + Free Store Pickup
# 168                                       More Options
# 169                                       More Options
# 170             after $5 Rebate + Free In-Store Pickup
# 171             after $5 Rebate + Free In-Store Pickup
# 172             after $5 Rebate + Free In-Store Pickup
# 173    + Free Shipping and Handling with Email Sign-Up
# 174    + Free Shipping and Handling with Email Sign-Up
# 175                           (Mobile Device Required)
# 176                                       More Options
# 177                                       More Options
# 178                                       More Options
# 179                                       More Options
# 180                                    + Free Shipping
# 181                       + Free Shipping and Handling
# 182                       + Free Shipping and Handling
#
#                                                   Item                 Price  \
# 0                Starwood Preferred Guest® Credit Card  Up to 35K Starpoints
# 1    Xiaomi Mi Band 2 Heart Rate Monitor Smart Brac...                   $20
# 2    40-Piece Outdoor Sports GoPro Camera Accessory...                 $8.90
# 3                       Blue Cash Everyday Credit Card       Up to $300 Back
# 4    TaxAct Online Federal & State Tax Services: Pr...                 $7.50
# 5    Canon imageCLASS MF249dw All-In-One Laser Printer                  $149
# 6                    Chase Ink Business Preferred Card            80K Points
# 173  Cellucor C4 50X Pre-Workout Supplement (45-Ser...             2 for $30
# 174  Reed, Infinity Loop Premium, Bloons TD 5 (Andr...                  Free
# 175  UNIQLO In-Store Offer: Men's or Women's AIRism...                  Free
# 176                   Aden + Anais: Toddler Bed in Bag                $49.50
# 177  Select Walmart Stores: Bike Clearance: Men's &...              from $17
# 178  Daniel Tiger's Neighborhood Board Books (Various)            from $2.50
# 179                           Love You To Bits for iOS                  Free
# 180  RAVPower 20100mAh Quick Charge 3.0 Portable Ba...                   $36
# 181  16GB (2x8GB) Avexir Core Series DDR4 Desktop M...                   $80
# 182  Walmart Stores: 2-Piece Sheffield Precision To...                 $1.25
#
#                       Retailer  \
# 0                         Amex
# 1             Light In The Box
# 2                       Amazon
# 3                         Amex
# 4                       TaxAct
# 5                      Adorama
# 6                        Chase
# 7                       Amazon
# 8                        Dell
# 9                          REI
# 10                      Macy's
# 11                      Macy's
# 12                       Dell
# 13                     Walmart
# 14                       Dell
# 15                    Best Buy
# 16                       Chase
# 17                       Dell
# 18                        Amex
# 19                       Chase
# 20                        Amex
# 21                       Chase
# 22                  FreedomPop
# 23                   Patagonia
# 24                    T-Mobile
# 25                  Home Depot
# 26                    T-Mobile
# 27            Verizon Wireless
# 28            Verizon Wireless
# 29                     Walmart
# ..                         ...
# 153          Playstation Store
# 154                   Best Buy
# 155                   Best Buy
# 156                  Priceline
# 157                  Priceline
# 158                   GameStop
# 159                 Food Saver
# 160                    Walmart
# 161                 Papa Johns
# 162          Red Pocket Mobile
# 163                     Amazon
# 164  Academy Sports + Outdoors
# 165                    Walmart
# 166                     Amazon
# 167             Nintendo eShop
# 168                     Amazon
# 169                   TorGuard
# 170         Advance Auto Parts
# 171                  Twitch.TV
# 172                   Cheerios
# 173                   Cellucor
# 174                Google Play
# 175                     UNIQLO
# 176                     Amazon
# 177             Walmart Stores
# 178                     Amazon
# 179               Apple iTunes
# 180                     Amazon
# 181                     Amazon
# 182                    Walmart
#
#                                                 Source
# 0    https://slickdeals.net/f/9778931-starwood-pref...
# 1    https://slickdeals.net/f/9849608-xiaomi-mi-ban...
# 2    https://slickdeals.net/f/9204751-40-piece-outd...
# 3    https://slickdeals.net/f/9802163-blue-cash-eve...
# 4    https://slickdeals.net/f/9865688-taxact-online...
# 5    https://slickdeals.net/f/9707596-canon-imagecl...
# 6    https://slickdeals.net/f/9205591-chase-ink-bus...
# 7    https://slickdeals.net/f/9204751-40-piece-outd...
# 8    https://slickdeals.net/f/9849488-new-dell-insp...
# 9    https://slickdeals.net/f/9863404-marmot-greenr...
# 10   https://slickdeals.net/f/9868392-macy-s-15-off...
# 11   https://slickdeals.net/f/9868396-macy-s-vip-sa...
# 12   https://slickdeals.net/f/9866324-dell-xps-8910...
# 13   https://slickdeals.net/f/9853316-dell-inspiron...
# 14   https://slickdeals.net/f/9862304-55-samsung-un...
# 15   https://slickdeals.net/f/9861960-40-samsung-un...
# 16   https://slickdeals.net/f/9205591-chase-ink-bus...
# 17   https://slickdeals.net/f/9854468-22-dell-s2216...
# 21       Chase - Bank Advertiser
# 22                    FreedomPop
# 23                     Patagonia
# 24                      T-Mobile
# 25                    Home Depot
# 26                      T-Mobile
# 27              Verizon Wireless
# 28              Verizon Wireless
# 29                       Walmart
#                  ...
# 153            Playstation Store
# 154                     Best Buy
# 155                     Best Buy
# 156                    Priceline
# 157                    Priceline
# 158                     GameStop
# 159                   Food Saver
# 160                      Walmart
# 161                   Papa Johns
# 162            Red Pocket Mobile
# 163                       Amazon
# 164    Academy Sports + Outdoors
# 165                      Walmart
# 166                       Amazon
# 167               Nintendo eShop
# 168                       Amazon
# 169                     TorGuard
# 170           Advance Auto Parts
# 171                    Twitch.TV
# 172                     Cheerios
# 173                 Cellucor.com
# 174                  Google Play
# 175                       UNIQLO
# 176                       Amazon
# 177               Walmart Stores
# 178                       Amazon
# 179                 Apple iTunes
# 180                       Amazon
# 181                       Amazon
# 182                      Walmart
# Name: Retailer, dtype: object

# %%
data2.Price
# Out:
# 0      Up to 35K Starpoints
# 1                        $1
# 2                      $149
# 3                      $325
# 4                     $1.60
# 5                       $20
# 6                50K Points
# 7                      $690
# 8              $499 or Less
# 9                     $1100
# 10                     $300
# 11               80K Points
# 12                      $60
# 13          Up to $300 Back
# 14          Up to $300 Back
# 15     Up to 35K Starpoints
# 16               50K Points
# 17                       $1
# 18            Up to 50% Off
# 19                     $110
# 20                      $89
# 21               $100/Month
# 22           From $80/Month
# 23                     $144
# 24            Up to 30% off
# 25                   $29.75
# 26                      $12
# 27                    $5.60
# 28              $13 or less
# 29                      $51
#                ...
# 140                   $1.25
# 141                    $550
# 142                   $7.50
# 143                     $10
# 144                    $750
# 145                     $80
# 146                     $20
# 147                     $11
# 148                    Free
# 149                   $3.20
# 150                    $490
# 151        From 6 for $7.60
# 152                     $48
# 153                    Free
# 154                    Free
# 155                   $5.10
# 156                   $6.90
# 157                  $12.50
# 158               from $725
# 159                     $51
# 160                      $5
# 161                 50% Off
# 162                   $9.50
# 163                    Free
# 164                    Free
# 165               $660 each
# 166                  $11.65
# 167                     $30
# 168                    Free
# 169               B1G1 Free
# Name: Price, dtype: object

# %%
# Clean up location data to ensure consistency
#data['Extra Info'].replace({'w/' : 'with',
                        #    '& More' : "More Options"
                        # }, inplace=True)
        
data['Extra Info'].replace({'w/' : 'with'
                         }, regex=True, inplace=True)
    
data['Extra Info'].replace({'& More' : 'More Options'
                         }, regex=True, inplace=True)
data['Extra Info'].replace({'S&H' : 'Shipping and Handling'
                         }, regex=True, inplace=True)
data['Extra Info'].replace({'S/H' : 'Shipping and Handling'
                         }, regex=True, inplace=True)        

data2['Extra Info'].replace({'w/' : 'with'
                         }, regex=True, inplace=True)
    
data2['Extra Info'].replace({'& More' : 'More Options'
                         }, regex=True, inplace=True)
data2['Extra Info'].replace({'S&H' : 'Shipping and Handling'
                         }, regex=True, inplace=True)
data2['Extra Info'].replace({'S/H' : 'Shipping and Handling'
                         }, regex=True, inplace=True)

# %%
set(data['Extra Info'])
set(data2['Extra Info'])
# Out:
# {'& Many More for Xbox One/360',
#  '(Account Req.)',
#  '(Carryout Only)',
#  '(Mobile Device Required)',
#  '(New Customers Only)',
#  '(New Subscribers)',
#  '(Select States)',
#  '(Travel Apr-Aug)',
#  '(Travel Apr-Dec)',
#  '(Travel Mar - May or Aug - Nov)',
#  '(Travel Sep-Nov)',
#  '(Valid 3/14 Only)',
#  '(Valid for New Members)',
#  '(with Cartwheel)',
#  '+ Free In-Store Pickup',
#  '+ Free Shipping',
#  '+ Free Shipping and Handling',
#  '+ Free Shipping and Handling for Prime Members',
#  '+ Free Shipping and Handling on $49+',
#  '+ Free Shipping and Handling on $75+',
#  '+ Free Shipping and Handling with Email Sign-Up',
#  '+ Free Store Pick-Up',
#  '+ Free Store Pickup',
#  '+ Ship to Store on $25+',
#  '1% Cashback (Terms Apply)',
#  'More Options',
#  'More Options (Travel April, May & Jan)',
#  'More Options (with Email Code)',
#  'More Options + Free Shipping',
#  'More Options + Free Shipping and Handling',
#  'More Options + Free Store Pickup',
#  'Terms Apply',
#  'after $15 Rebate + Free Shipping and Handling',
#  'after $20 Rebate',
#  'after $30 Rebate',
#  'after $5 Rebate + Free In-Store Pickup',
#  'after $50 Slickdeals Rebate',
#  'or Less + Free Shipping and Handling',
#  'via Printable Coupon',
#  'with $4K Spent in 1st 3-Mos',
#  'with $5K Spent in 1st 3-mos',
#  'with Auto Pay',
#  'with AutoPay'}

# %%
data['Retailer'].replace({' - Bank Advertiser' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({' - Bank Advertiser' : ''
                         }, regex=True, inplace=True)
data['Retailer'].replace({'.com' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({'.com' : ''
                         }, regex=True, inplace=True)
data['Retailer'].replace({'Small Business' : ''
                         }, regex=True, inplace=True)
data['Retailer'].replace({'EPP' : ''
                         }, regex=True, inplace=True)
data['Retailer'].replace({'Home & Office' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({'Small Business' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({'EPP' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({'Home & Office' : ''
                         }, regex=True, inplace=True)

# %%
set(data['Retailer'])
set(data2['Retailer'])
# Out:
# {'A4C',
#  'Academy Sports + Outdoors',
#  'Adorama',
#  'Advance Auto Parts',
#  'Amazon',
#  'Amex',
#  'Apple iTunes',
#  'B&H Photo Video',
#  'Bare Necessities',
#  'Best Buy',
#  'Blaze Pizza',
#  'Cafe Rio Mexican Grill',
#  'Canon',
#  'Cellucor',
#  'Charlotte Russe',
#  'Chase',
#  'Cheerios',
#  'Corner Bakery Cafe',
#  'Daily Steals',
#  'Dell ',
#  'DiscountMags',
#  'Dominos Pizza',
#  'EA Origin',
#  'Emirates US',
#  'Expedia',
#  'Focus Camera',
#  'Food Saver',
#  'FreedomPop',
#  'Frys',
#  'GameStop',
#  'Gilt City',
#  'Google Play',
#  'Green Man Gaming',
#  'Groupon',
#  'Home Decorators Collection',
#  'Home Depot',
#  'JCPenney',
#  'Kmart',
#  'Light In The Box',
#  "Lowe's",
#  "Macy's",
#  'Microsoft Store',
#  'Mr. Coffee',
#  'Newegg',
#  'Nintendo eShop',
#  'Nordstrom',
#  'Office Depot and OfficeMax',
#  'Papa Johns',
#  'Patagonia',
#  'Playstation Store',
#  'Priceline',
#  'REI',
#  'Red Pocket Mobile',
#  'Samsung',
#  'Sears',
#  'StackSocial',
#  'Supplement Hunt',
#  'T-Mobile',
#  'Tanga',
#  'Target',
#  'Target Stores',
#  'TaxAct',
#  'TorGuard',
#  'Toys R Us',
#  'Twitch.TV',
#  'UNIQLO',
#  'Verizon Wireless',
#  'Virgin America',
#  'Walmart',
#  'Walmart Stores',
#  'Xbox',
#  'XtremeGuard',
#  'eBay',
#  'iTechDeals'}

# %%
NoDupsData = data.drop_duplicates()
NoDupsData2 = data2.drop_duplicates()

# %% [markdown]
# ###### 3. Merge dataframes from separate json files as appropriate
# - Find the intersection of two (or more) sets
# - Compare the intersection with the newer set to find 'New Products'
#     - When found, add the starting date
# - Compare the intersection with the older set to find 'Closed Products'
#     - When found, add the closing date
#     - Compare closing date with starting date to find days on market

# %%
# Create the inner merge of the two dataframes
dataInnerMerge = pd.merge(NoDupsData, NoDupsData2, \
                          on=['ID','Location','Title','Price'],\
                          how='inner')

# %%
# Determine the set of 'new products'
NoDupsData2['key1'] = 1
dataInnerMerge['key2'] = 1
newProducts = pd.merge(NoDupsData2, dataInnerMerge, \
                      on=['ID', 'Title','Location','Price'], \
                      how = 'left')

# Create the associated dataframe
newProducts = newProducts[newProducts.key2 != newProducts.key1]

# Add the starting date in the dataframe in which the product is first shown

# %%
# Determine the set of 'closed products'
NoDupsData['key1'] = 1
closedProducts = pd.merge(NoDupsData, dataInnerMerge, \
                      on=['ID', 'Title','Location','Price'], \
                      how = 'left')

# Create the associated dataframe
closedProducts = closedProducts[closedProducts.key2 != closedProducts.key1]

# Add the closing date in the dataframe in which the product is last shown


# Find days on market by comparing the starting date with the closing date

# %% [markdown]
# ###### 4. Create visualizations
# - Histogram of Prices
# - Histogram of Days on Market
# - Scatter Diagram of Prices vs Days on Market
# - Pie Chart of New, Like New, Used

# %%
# Create a histogram of Prices
goodPrices = newProducts.Price[newProducts['Price'] > 1.0]
goodPrices = goodPrices[goodPrices < 1500.0]
plt.hist(goodPrices)
plt.title("Product Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

#Temporary Data for Days on Market ... for Scatter Plot Example
scatterData = {'Price': goodPrices,\
               'daysOnMarket' : \
               np.random.randint(1,30,size=len(goodPrices))}
sD = pd.DataFrame(scatterData)

# Create a histogram of Days on Market
plt.hist(sD.daysOnMarket)
plt.title("Days On Market")
plt.xlabel("Days")
plt.ylabel("Frequency")
plt.show()

# Create a Scatter Diagram of Prices vs Days on Market
fig = plt.figure()
ax = fig.add_subplot(111)
x = sD.Price
y = sD.daysOnMarket
ax.scatter(x,y,color='blue')
ax.set_ylim([0,30])
ax.set_xlim([0,1600])

plt.title("Days On Market vs Price")
plt.xlabel("Price")
plt.ylabel("Days On Market")
plt.show()

# Create a Pie Chart of New, Like New, and Used products
colors = ["#E13F29", "#D69A80", "#D63B59"]
# Create a pie chart
plt.pie(
    [newProducts.Condition[newProducts.Condition == 'like new'].count(),\
     newProducts.Condition[newProducts.Condition == 'new'].count(), \
     newProducts.Condition[newProducts.Condition == 'used'].count()],
    labels= ['like_new','new','used'],
    shadow=True,
    # with colors
    colors=colors,
    # with one slide exploded out
    explode=(0.1, 0, 0),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%1.1f%%',
    )

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### 5. Trends from your data
# - Search for specific brands and offer counts for each
# - Search for product types and offer counts for each
# - For each of the above (and other) give counts for day over day or week over week

# %%
# List the products representing specific brands of your choosing
# for each date provided
fenderData = NoDupsData[NoDupsData['Title'].str.contains('fender ')]
yamahaData = NoDupsData[NoDupsData['Title'].str.contains('yamaha ')]
gibsonData = NoDupsData[NoDupsData['Title'].str.contains('gibson ')]
fenderData2 = NoDupsData2[NoDupsData2['Title'].str.contains('fender ')]
yamahaData2 = NoDupsData2[NoDupsData2['Title'].str.contains('yamaha ')]
gibsonData2 = NoDupsData2[NoDupsData2['Title'].str.contains('gibson ')]

# Create a bar chart of products by brand (for the brands chosen)
fenderCount = len(fenderData)
yamahaCount = len(yamahaData)
gibsonCount = len(gibsonData)
fenderCount2 = len(fenderData2)
yamahaCount2 = len(yamahaData2)
gibsonCount2 = len(gibsonData2)

objects = ('Fender','Fender2','', 'Yamaha', 'Yamaha2','', \
           'Gibson', 'Gibson2')
colors = ('green','red','blue','green','red','blue','green','red')
y_pos = np.arange(len(objects))
performance = [fenderCount,fenderCount2,0,yamahaCount,yamahaCount2,\
               0,gibsonCount,gibsonCount2]
fig = plt.figure(figsize=(15,7))
plt.bar(y_pos, performance, align='center',alpha=0.5, color=colors)
plt.xticks(y_pos, objects)
plt.ylabel('Counts')
plt.title('Brands')
 
plt.show()

# List the products of a specific type
guitarData = NoDupsData[NoDupsData['Title'].str.contains('guitar ')]
audioData = NoDupsData[NoDupsData['Title'].str.contains('audio ')]
drumData = NoDupsData[NoDupsData['Title'].str.contains('drum ')]
guitarData2 = NoDupsData2[NoDupsData2['Title'].str.contains('guitar ')]
audioData2 = NoDupsData2[NoDupsData2['Title'].str.contains('audio ')]
drumData2 = NoDupsData2[NoDupsData2['Title'].str.contains('drum ')]


# Create a bar chart of products by specific type
# for each date provided
guitarCount = len(guitarData)
audioCount = len(audioData)
drumCount = len(drumData)
guitarCount2 = len(guitarData2)
audioCount2 = len(audioData2)
drumCount2 = len(drumData2)

objects = ('Guitar','Guitar2','', 'Audio','Audio2','', 'Drum','Drum2')
y_pos = np.arange(len(objects))
performance = [guitarCount,guitarCount2,0,audioCount,audioCount2,\
               0,drumCount,drumCount2]
colors = ('green','red','blue','green','red','blue','green','red') 
plt.bar(y_pos, performance, align='center', alpha=0.5, color=colors)
plt.xticks(y_pos, objects)
plt.ylabel('Counts')
plt.title('Product Type')
 
plt.show()

# %%
fenderData[['Link','Title']]

# %%
drumData[['Link','Title']]
