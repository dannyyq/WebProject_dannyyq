# %%
##Questions of Interest
#1. Which retailer has the most frequent appearances on Slickdeals?
#2. Are there more cheaper items or more expensive items on Slickdeals?
#3. How many items are sold for a certain amount of money compared to items that deal with points and other ways of paying?
#4. Do the most frequent sellers change over time, or do they remain constant?

#I plan to do at least 1 and 2, and possibly get into 3.

# %% [markdown]
# ## Creating a Web Data Project with Jupyter Notebooks
# ******
# ###### 1. Read in json file(s) resulting from your work with requests/selenium and beautifulsoup

# %%
# Import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# Read in json files and create dataframes
filename = '2017-03-16.SDNewsBriefs.json'
data = pd.read_json(filename)
filename2 = '2017-03-14.SDNewsBriefs.json'
data2 = pd.read_json(filename2)

# %% [markdown]
# ###### 2. Clean the data column by column
# - Ensure that addresses (or other text data) are consistent
# - Eliminate string characters from numeric values
# - Exclude redundant data as appropriate

# %%
data
# Out:
#                                  Extra Info  \
# 0                               Terms Apply
# 1                               Terms Apply
# 2                         & More + Free S&H
# 3                 w/ $5K Spent in 1st 3-mos
# 4                           + Free Shipping
# 5                      (New Customers Only)
# 6                & More + Free Store Pickup
# 7                & More + Free Store Pickup
# 8                & More + Free Store Pickup
# 9                           + Free Shipping
# 10                   & More + Free Shipping
# 11                   & More + Free Shipping
# 12                   & More + Free Shipping
# 13                          + Free Shipping
# 14                          + Free Shipping
# 15                          + Free Shipping
# 16                w/ $5K Spent in 1st 3-mos
# 17                w/ $5K Spent in 1st 3-mos
# 18                1% Cashback (Terms Apply)
# 19                1% Cashback (Terms Apply)
# 20                              Terms Apply
# 21                w/ $4K Spent in 1st 3-Mos
# 22                          + Free Shipping
# 23                       + Free S&H on $75+
# 24                       + Free S&H on $75+
# 25                       + Free S&H on $75+
# 26                               w/ AutoPay
# 27                              w/ Auto Pay
# 28                              w/ Auto Pay
# 29                          + Free Shipping
# ..                                      ...
# 158                                  & More
# 159                                  & More
# 160                                  & More
# 161                        (Travel Apr-Dec)
# 162                        (Travel Sep-Nov)
# 163                        (Travel Sep-Nov)
# 164                        (Travel Sep-Nov)
# 165                  & More + Free Shipping
# 166                  & More + Free Shipping
# 167                  & More + Free Shipping
# 168                  & More + Free Shipping
# 169                  & More + Free Shipping
# 170                     + Free Store Pickup
# 171                     + Free Store Pickup
# 172                     + Free Store Pickup
# 173                                  & More
# 174                                  & More
# 175  after $5 Rebate + Free In-Store Pickup
# 176  after $5 Rebate + Free In-Store Pickup
# 177  after $5 Rebate + Free In-Store Pickup
# 178             + Free S/H w/ Email Sign-Up
# 179             + Free S/H w/ Email Sign-Up
# 180                (Mobile Device Required)
# 181                (Mobile Device Required)
# 182                (Mobile Device Required)
# 183                (Mobile Device Required)
# 184                (Mobile Device Required)
# 185                (Mobile Device Required)
# 186                              + Free S/H
# 187                              + Free S/H
#
#                                                   Item                 Price  \
# 0                Starwood Preferred Guest® Credit Card  Up to 35K Starpoints
# 1    Slate® by Chase Intro Offer: 0% APR for 15 Mon...  Up to 35K Starpoints
# 2    Pioneer DJ Controller Sale: DDJ-SX2 4ch $820, ...                  $490
# 3                    Chase Ink Business Preferred Card            80K Points
# 4    Rokinon 14mm f/2.8 Lens: Nikon w/ AF Clip $279...                  $249
# 5    TaxAct Online Federal & State Tax Services: Pr...                 $7.50
# 6    Macy's VIP Sale w/ Up to 30% Off: 32 Degrees M...                 $4.20
# 7    40-Piece Outdoor Sports GoPro Camera Accessory...                 $8.90
# 8      Dell Inspiron 15 Laptop: i5-7300HQ, GTX 1050 
# 156  https://slickdeals.net/f/9846840-6-92-crock-po...
# 157  https://slickdeals.net/f/9821179-6-pack-of-16g...
# 158  https://slickdeals.net/f/9846204-roundtrip-fli...
# 159  https://slickdeals.net/f/9843455-2-years-of-pr...
# 160  https://slickdeals.net/f/9795467-12-pack-oral-...
# 161  https://slickdeals.net/f/9845432-b-h-50-off-deals
# 162  https://slickdeals.net/f/9845348-4-pack-of-80-...
# 163  https://slickdeals.net/f/9845904-ps4-themes-ni...
# 164  https://slickdeals.net/f/9824615-playstation-p...
# 165  https://slickdeals.net/f/9839415-samsung-5-0-c...
# 166  https://slickdeals.net/f/9841215-contigo-autos...
# 167  https://slickdeals.net/f/9839939-xbox-one-arme...
# 168  https://slickdeals.net/f/9844095-4-months-of-g...
# 169  https://slickdeals.net/f/9841675-cafe-rio-bogo...
#
# [170 rows x 5 columns]

# %%
data.Retailer
# Out:
# 0         Amex - Bank Advertiser
# 1        Chase - Bank Advertiser
# 2                        Adorama
# 3        Chase - Bank Advertiser
# 4                        Adorama
# 5                         TaxAct
# 6                         Macy's
# 7                         Amazon
# 8                       Dell EPP
# 9                            REI
# 10                        Macy's
# 11                        Macy's
# 12           Dell Small Business
# 13                       Walmart
# 14                      Dell EPP
# 15                      Best Buy
# 16       Chase - Bank Advertiser
# 17            Dell Home & Office
# 18        Amex - Bank Advertiser
# 19       Chase - Bank Advertiser
# 20        Amex - Bank Advertiser
# 21       Chase - Bank Advertiser
# 22                    FreedomPop
# 23                     Patagonia
# 24                      T-Mobile
# 25                    Home Depot
# 26                      T-Mobile
# 27              Verizon Wireless
# 28                      Fidelity
# 29                          eBay
#                  ...
# 158            Playstation Store
# 159                     Best Buy
# 160                     Best Buy
# 161                    Priceline
# 162                    Priceline
# 163                     GameStop
# 164                   Food Saver
# 165                      Walmart
# 166                   Papa Johns
# 167            Red Pocket Mobile
# 168                       Amazon
# 169    Academy Sports + Outdoors
# 170                      Walmart
# 171                       Amazon
# 172               Nintendo eShop
# 173                       Amazon
# 174                     TorGuard
# 175           Advance Auto Parts
# 176                    Twitch.TV
# 177                     Cheerios
# 178                 Cellucor.com
# 179                  Google Play
# 180                       UNIQLO
# 181                       Amazon
# 182               Walmart Stores
# 183                       Amazon
# 184                 Apple iTunes
# 185                       Amazon
# 186                       Amazon
# 187                      Walmart
# Name: Retailer, dtype: object

# %%
set(data2.Price)
# Out:
# {'$0.40',
#  '$1',
#  '$1 Each',
#  '$1.25',
#  '$1.60',
#  '$10',
#  '$10/ Month',
#  '$10/year',
#  '$100',
#  '$100/Month',
#  '$11',
#  '$11.65',
#  '$110',
#  '$1100',
#  '$12',
#  '$12.50',
#  '$12.75',
#  '$12.80',
#  '$13 or less',
#  '$13.20 each',
#  '$14',
#  '$144',
#  '$149',
#  '$15',
#  '$15.60',
#  '$159',
#  '$16',
#  '$16.80',
#  '$18',
#  '$19',
#  '$2 Each',
#  '$2.10',
#  '$2.40',
#  '$20',
#  '$20.60',
#  '$200',
#  '$23.50/year',
#  '$24',
#  '$270',
#  '$28',
#  '$29.50',
#  '$29.75',
#  '$299',
#  '$3',
#  '$3.14 Each',
#  '$3.20',
#  '$3.90',
#  '$30',
#  '$30.60',
#  '$300',
#  '$325',
#  '$35',
#  '$36',
#  '$362',
#  '$38',
#  '$4.20',
#  '$4.55',
#  '$48',
#  '$49.50',
#  '$490',
#  '$495',
#  '$499',
#  '$499 or Less',
#  '$5',
#  '$5 Credit',
#  '$5 each',
#  '$5.10',
#  '$5.60',
#  '$50',
#  '$51',
#  '$54.90',
#  '$550',
#  '$569',
#  '$6.60',
#  '$6.75',
#  '$6.90',
#  '$60',
#  '$61',
#  '$660 each',
#  '$690',
#  '$7.50',
#  '$7.55',
#  '$700',
#  '$750',
#  '$799',
#  '$8',
#  '$8.30',
#  '$8.35',
#  '$80',
#  '$800',
#  '$84',
#  '$88',
#  '$89',
#  '$9.50',
#  '$9.70',
#  '$9.75',
#  '$90',
#  '2 for $30',
#  '3 for $12',
#  '35% Off',
#  '50% Off',
#  '50K Points',
#  '80K Points',
#  'B1G1 Free',
#  'Free',
#  'From $80/Month',
#  'From 6 for $7.60',
#  'Up to $300 Back',
#  'Up to 30% off',
#  'Up to 35K Starpoints',
#  'Up to 50% Off',
#  'from $0.60',
#  'from $1.75',
#  'from $138',
#  'from $17',
#  'from $2.50',
#  'from $21.50',
#  'from $3.98',
#  'from $490',
#  'from $532',
#  'from $725'}

# %%
#Before cleanup
set(data['Extra Info'])
# Out:
# {'& Many More for Xbox One/360',
#  '(Carryout Only)',
#  '(Mobile Device Required)',
#  '(New Customers Only)',
#  '(New Customers) + Free Shipping and Handling',
#  '(Select Theaters)',
#  '(Travel Apr-Dec)',
#  '(Travel Sep-Nov)',
#  '(Travel Sept - Nov)',
#  '(Valid for Select Cardholders)',
#  '(XBL Gold Membership Req.)',
#  '+ $3.99 Shipping and Handling or FS on $35+',
#  '+ $5 Flat-Rate Shipping and Handling',
#  '+ Free In-Store Pickup',
#  '+ Free Shipping',
#  '+ Free Shipping and Handling',
#  '+ Free Shipping and Handling (VZW Customers Only)',
#  '+ Free Shipping and Handling on $25+',
#  '+ Free Shipping and Handling on $50+',
#  '+ Free Shipping and Handling on $75+',
#  '+ Free Shipping and Handling with Elevated Rewards',
#  '+ Free Shipping and Handling with Email Sign-Up',
#  '+ Free Store Pickup',
#  '1% Cashback (Terms Apply)',
#  'More Options',
#  'More Options + $3 Flat-Rate Shipping and Handling',
#  'More Options + Free Shipping',
#  'More Options + Free Shipping and Handling',
#  'More Options + Free Shipping and Handling Orders $125+',
#  'More Options + Free Shipping and Handling on $50+',
#  'More Options + Free Store Pickup',
#  'Terms Apply',
#  'after $20 Rebate',
#  'after $5 Rebate + Free In-Store Pickup',
#  'to Select Charity (Valid March 16 Only)',
#  'via Printable Coupon',
#  'with $4K Spent in 1st 3-Mos',
#  'with $5K Spent in 1st 3-mos',
#  'with Auto Pay',
#  'with AutoPay'}

# %%
#Before cleanup
set(data2['Extra Info'])

# %%
# Cleaning up Extra Info
        
data['Extra Info'].replace({'w/' : 'with'
                         }, regex=True, inplace=True)
    
data['Extra Info'].replace({'& More' : 'More Options'
                         }, regex=True, inplace=True)
data['Extra Info'].replace({'S&H' : 'Shipping and Handling'
                         }, regex=True, inplace=True)
data['Extra Info'].replace({'S/H' : 'Shipping and Handling'
                         }, regex=True, inplace=True)        

data2['Extra Info'].replace({'w/' : 'with'
                         }, regex=True, inplace=True)
    
data2['Extra Info'].replace({'& More' : 'More Options'
                         }, regex=True, inplace=True)
data2['Extra Info'].replace({'S&H' : 'Shipping and Handling'
                         }, regex=True, inplace=True)
data2['Extra Info'].replace({'S/H' : 'Shipping and Handling'
                         }, regex=True, inplace=True)

# %%
#After cleanup
set(data['Extra Info'])
# Out:
# {'& Many More for Xbox One/360',
#  '(Account Req.)',
#  '(Carryout Only)',
#  '(Mobile Device Required)',
#  '(New Customers Only)',
#  '(New Subscribers)',
#  '(Select States)',
#  '(Travel Apr-Aug)',
#  '(Travel Apr-Dec)',
#  '(Travel Mar - May or Aug - Nov)',
#  '(Travel Sep-Nov)',
#  '(Valid 3/14 Only)',
#  '(Valid for New Members)',
#  '(with Cartwheel)',
#  '+ Free In-Store Pickup',
#  '+ Free Shipping',
#  '+ Free Shipping and Handling',
#  '+ Free Shipping and Handling for Prime Members',
#  '+ Free Shipping and Handling on $49+',
#  '+ Free Shipping and Handling on $75+',
#  '+ Free Shipping and Handling with Email Sign-Up',
#  '+ Free Store Pick-Up',
#  '+ Free Store Pickup',
#  '+ Ship to Store on $25+',
#  '1% Cashback (Terms Apply)',
#  'More Options',
#  'More Options (Travel April, May & Jan)',
#  'More Options (with Email Code)',
#  'More Options + Free Shipping',
#  'More Options + Free Shipping and Handling',
#  'More Options + Free Store Pickup',
#  'Terms Apply',
#  'after $15 Rebate + Free Shipping and Handling',
#  'after $20 Rebate',
#  'after $30 Rebate',
#  'after $5 Rebate + Free In-Store Pickup',
#  'after $50 Slickdeals Rebate',
#  'or Less + Free Shipping and Handling',
#  'via Printable Coupon',
#  'with $4K Spent in 1st 3-Mos',
#  'with $5K Spent in 1st 3-mos',
#  'with Auto Pay',
#  'with AutoPay'}

# %%
#After cleanup
set(data2['Extra Info'])

# %%
#Before cleanup
set(data['Retailer'])

# %%
#Before cleanup
set(data2['Retailer'])

# %%
#Cleaning up Retailer names

data['Retailer'].replace({' - Bank Advertiser' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({' - Bank Advertiser' : ''
                         }, regex=True, inplace=True)
data['Retailer'].replace({'.com' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({'.com' : ''
                         }, regex=True, inplace=True)
data['Retailer'].replace({'Small Business' : ''
                         }, regex=True, inplace=True)
data['Retailer'].replace({'EPP' : ''
                         }, regex=True, inplace=True)
data['Retailer'].replace({'Home & Office' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({'Small Business' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({'EPP' : ''
                         }, regex=True, inplace=True)
data2['Retailer'].replace({'Home & Office' : ''
                         }, regex=True, inplace=True)
#Difficulties were that it wasnt replacing until I put regex true and inplace true

# %%
#After cleanup
set(data['Retailer'])
# Out:
# {'A4C',
#  'Academy Sports + Outdoors',
#  'Adorama',
#  'Advance Auto Parts',
#  'Amazon',
#  'Amex',
#  'Apple iTunes',
#  'B&H Photo Video',
#  'Bare Necessities',
#  'Best Buy',
#  'Blaze Pizza',
#  'Cafe Rio Mexican Grill',
#  'Canon',
#  'Cellucor',
#  'Charlotte Russe',
#  'Chase',
#  'Cheerios',
#  'Corner Bakery Cafe',
#  'Daily Steals',
#  'Dell ',
#  'DiscountMags',
#  'Dominos Pizza',
#  'EA Origin',
#  'Emirates US',
#  'Expedia',
#  'Focus Camera',
#  'Food Saver',
#  'FreedomPop',
#  'Frys',
#  'GameStop',
#  'Gilt City',
#  'Google Play',
#  'Green Man Gaming',
#  'Groupon',
#  'Home Decorators Collection',
#  'Home Depot',
#  'JCPenney',
#  'Kmart',
#  'Light In The Box',
#  "Lowe's",
#  "Macy's",
#  'Microsoft Store',
#  'Mr. Coffee',
#  'Newegg',
#  'Nintendo eShop',
#  'Nordstrom',
#  'Office Depot and OfficeMax',
#  'Papa Johns',
#  'Patagonia',
#  'Playstation Store',
#  'Priceline',
#  'REI',
#  'Red Pocket Mobile',
#  'Samsung',
#  'Sears',
#  'StackSocial',
#  'Supplement Hunt',
#  'T-Mobile',
#  'Tanga',
#  'Target',
#  'Target Stores',
#  'TaxAct',
#  'TorGuard',
#  'Toys R Us',
#  'Twitch.TV',
#  'UNIQLO',
#  'Verizon Wireless',
#  'Virgin America',
#  'Walmart',
#  'Walmart Stores',
#  'Xbox',
#  'XtremeGuard',
#  'eBay',
#  'iTechDeals'}

# %%
#After cleanup
set(data2['Retailer'])

# %%
#Before cleanup
set(data['Price'])
# Out:
# {'$1',
#  '$1.25',
#  '$1.50',
#  '$1.80',
#  '$10',
#  '$10 Credit',
#  '$10.45',
#  '$10/ Month',
#  '$100',
#  '$100/Month',
#  '$11.40',
#  '$11.70',
#  '$110',
#  '$1100',
#  '$12',
#  '$12.80',
#  '$125',
#  '$13',
#  '$13.20',
#  '$13.90',
#  '$14',
#  '$14.80',
#  '$144',
#  '$1497',
#  '$1499',
#  '$15',
#  '$15.60',
#  '$150',
#  '$159',
#  '$16',
#  '$16.80',
#  '$161.50',
#  '$179',
#  '$18',
#  '$2',
#  '$2 Each',
#  '$2.10',
#  '$20',
#  '$20.60',
#  '$200',
#  '$21',
#  '$22',
#  '$22.50',
#  '$23',
#  '$23.50/year',
#  '$249',
#  '$250',
#  '$26',
#  '$270',
#  '$279',
#  '$28',
#  '$29.50',
#  '$29.75',
#  '$3',
#  '$3.75',
#  '$3.80',
#  '$3.90',
#  '$30',
#  '$300',
#  '$310',
#  '$349',
#  '$35',
#  '$36',
#  '$362',
#  '$4',
#  '$4.20',
#  '$43',
#  '$44',
#  '$450',
#  '$49.50',
#  '$490',
#  '$495',
#  '$498',
#  '$499',
#  '$499 or Less',
#  '$5',
#  '$5 Credit',
#  '$5 each',
#  '$5 per trade',
#  '$5.60',
#  '$5/yr',
#  '$50',
#  '$500',
#  '$52.50',
#  '$6',
#  '$6 Each',
#  '$6.40',
#  '$6.60',
#  '$6/yr',
#  '$60',
#  '$690',
#  '$7.50',
#  '$70',
#  '$750',
#  '$799',
#  '$8',
#  '$8 Each',
#  '$8.30',
#  '$8.35',
#  '$8.80',
#  '$8.90',
#  '$80',
#  '$800',
#  '$84',
#  '$85',
#  '$89',
#  '$9',
#  '$9.70',
#  '10 Bonus Stars',
#  '1000 Points',
#  '2 for $13.60',
#  '2 for $30',
#  '3 for $23',
#  '5% Donation',
#  '50% Off',
#  '50K Points',
#  '80K Points',
#  'B1G1 Free',
#  'Extra 30% off',
#  'Free',
#  'From $36',
#  'From $80/Month',
#  'Up to $300 Back',
#  'Up to 35K Starpoints',
#  'Up to 50% Off',
#  'from $0.60',
#  'from $1.75',
#  'from $17',
#  'from $17.50',
#  'from $2.50',
#  'from $21.50',
#  'from $3.50',
#  'from $5.60',
#  'from $532'}

# %%
#Before cleanup
set(data2['Price'])
# Out:
# {'$0.40',
#  '$1',
#  '$1 Each',
#  '$1.25',
#  '$1.60',
#  '$10',
#  '$10/ Month',
#  '$10/year',
#  '$100',
#  '$100/Month',
#  '$11',
#  '$11.65',
#  '$110',
#  '$1100',
#  '$12',
#  '$12.50',
#  '$12.75',
#  '$12.80',
#  '$13 or less',
#  '$13.20 each',
#  '$14',
#  '$144',
#  '$149',
#  '$15',
#  '$15.60',
#  '$159',
#  '$16',
#  '$16.80',
#  '$18',
#  '$19',
#  '$2 Each',
#  '$2.10',
#  '$2.40',
#  '$20',
#  '$20.60',
#  '$200',
#  '$23.50/year',
#  '$24',
#  '$270',
#  '$28',
#  '$29.50',
#  '$29.75',
#  '$299',
#  '$3',
#  '$3.14 Each',
#  '$3.20',
#  '$3.90',
#  '$30',
#  '$30.60',
#  '$300',
#  '$325',
#  '$35',
#  '$36',
#  '$362',
#  '$38',
#  '$4.20',
#  '$4.55',
#  '$48',
#  '$49.50',
#  '$490',
#  '$495',
#  '$499',
#  '$499 or Less',
#  '$5',
#  '$5 Credit',
#  '$5 each',
#  '$5.10',
#  '$5.60',
#  '$50',
#  '$51',
#  '$54.90',
#  '$550',
#  '$569',
#  '$6.60',
#  '$6.75',
#  '$6.90',
#  '$60',
#  '$61',
#  '$660 each',
#  '$690',
#  '$7.50',
#  '$7.55',
#  '$700',
#  '$750',
#  '$799',
#  '$8',
#  '$8.30',
#  '$8.35',
#  '$80',
#  '$800',
#  '$84',
#  '$88',
#  '$89',
#  '$9.50',
#  '$9.70',
#  '$9.75',
#  '$90',
#  '2 for $30',
#  '3 for $12',
#  '35% Off',
#  '50% Off',
#  '50K Points',
#  '80K Points',
#  'B1G1 Free',
#  'Free',
#  'From $80/Month',
#  'From 6 for $7.60',
#  'Up to $300 Back',
#  'Up to 30% off',
#  'Up to 35K Starpoints',
#  'Up to 50% Off',
#  'from $0.60',
#  'from $1.75',
#  'from $138',
#  'from $17',
#  'from $2.50',
#  'from $21.50',
#  'from $3.98',
#  'from $490',
#  'from $532',
#  'from $725'}

# %%
data['Price'] = data['Price'].str.replace('\/', '')

data['Price'] = data['Price'].str.replace(' month', '')
data['Price'] = data['Price'].str.replace('month', '')
data['Price'] = data['Price'].str.replace('Month', '')
data['Price'] = data['Price'].str.replace(' Month', '')
data['Price'] = data['Price'].str.replace('from ', '')
data['Price'] = data['Price'].str.replace('From ', '')
data['Price'] = data['Price'].str.replace(' Credit', '')
data['Price'] = data['Price'].str.replace('year ', '')
data['Price'] = data['Price'].str.replace('year', '')
data['Price'] = data['Price'].str.replace(' year ', '')
data['Price'] = data['Price'].str.replace('yr', '')
data['Price'] = data['Price'].str.replace(' or Less', '')
data['Price'] = data['Price'].str.replace(' each', '')
data['Price'] = data['Price'].str.replace(' per trade', '')
data['Price'] = data['Price'].str.replace(' Each', '')
data['Price'] = data['Price'].str.replace(' or less', '')

#data specific cases
data['Price'] = data['Price'].str.replace('2 for \$13.60', '\$6.80')
data['Price'] = data['Price'].str.replace('2 for \$30', '\$15')
data['Price'] = data['Price'].str.replace('3 for \$23', '\$7.67')
data['Price'] = data['Price'].str.replace('\\', '')


data2['Price'] = data2['Price'].str.replace('\/', '')

data2['Price'] = data2['Price'].str.replace(' month', '')
data2['Price'] = data2['Price'].str.replace('month', '')
data2['Price'] = data2['Price'].str.replace('Month', '')
data2['Price'] = data2['Price'].str.replace(' Month', '')
data2['Price'] = data2['Price'].str.replace('from ', '')
data2['Price'] = data2['Price'].str.replace('From ', '')
data2['Price'] = data2['Price'].str.replace(' Credit', '')
data2['Price'] = data2['Price'].str.replace('year ', '')
data2['Price'] = data2['Price'].str.replace('year', '')
data2['Price'] = data2['Price'].str.replace(' year ', '')
data2['Price'] = data2['Price'].str.replace('yr', '')
data2['Price'] = data2['Price'].str.replace(' or Less', '')
data2['Price'] = data2['Price'].str.replace(' each', '')
data2['Price'] = data2['Price'].str.replace(' per trade', '')
data2['Price'] = data2['Price'].str.replace(' Each', '')
data2['Price'] = data2['Price'].str.replace(' or less', '')

#data2 specific cases
data2['Price'] = data2['Price'].str.replace('3 for \$12', '\$4')
data2['Price'] = data2['Price'].str.replace('2 for \$30', '\$15')
data2['Price'] = data2['Price'].str.replace('6 for \$7.60', '\$1.27')
data2['Price'] = data2['Price'].str.replace('\\', '')

#Difficulty was using $ as a string to find

# %%
#After cleanup
set(data['Price'])
# Out:
# {'$0.60',
#  '$1',
#  '$1.25',
#  '$1.50',
#  '$1.75',
#  '$1.80',
#  '$10',
#  '$10 ',
#  '$10.45',
#  '$100',
#  '$11.40',
#  '$11.70',
#  '$110',
#  '$1100',
#  '$12',
#  '$12.80',
#  '$125',
#  '$13',
#  '$13.20',
#  '$13.90',
#  '$14',
#  '$14.80',
#  '$144',
#  '$1497',
#  '$1499',
#  '$15',
#  '$15.60',
#  '$150',
#  '$159',
#  '$16',
#  '$16.80',
#  '$161.50',
#  '$17',
#  '$17.50',
#  '$179',
#  '$18',
#  '$2',
#  '$2.10',
#  '$2.50',
#  '$20',
#  '$20.60',
#  '$200',
#  '$21',
#  '$21.50',
#  '$22',
#  '$22.50',
#  '$23',
#  '$23.50',
#  '$249',
#  '$250',
#  '$26',
#  '$270',
#  '$279',
#  '$28',
#  '$29.50',
#  '$29.75',
#  '$3',
#  '$3.50',
#  '$3.75',
#  '$3.80',
#  '$3.90',
#  '$30',
#  '$300',
#  '$310',
#  '$349',
#  '$35',
#  '$36',
#  '$362',
#  '$4',
#  '$4.20',
#  '$43',
#  '$44',
#  '$450',
#  '$49.50',
#  '$490',
#  '$495',
#  '$498',
#  '$499',
#  '$5',
#  '$5.60',
#  '$50',
#  '$500',
#  '$52.50',
#  '$532',
#  '$6',
#  '$6.40',
#  '$6.60',
#  '$6.80',
#  '$60',
#  '$690',
#  '$7.50',
#  '$7.67',
#  '$70',
#  '$750',
#  '$799',
#  '$8',
#  '$8.30',
#  '$8.35',
#  '$8.80',
#  '$8.90',
#  '$80',
#  '$800',
#  '$84',
#  '$85',
#  '$89',
#  '$9',
#  '$9.70',
#  '10 Bonus Stars',
#  '1000 Points',
#  '5% Donation',
#  '50% Off',
#  '50K Points',
#  '80K Points',
#  'B1G1 Free',
#  'Extra 30% off',
#  'Free',
#  'Up to $300 Back',
#  'Up to 35K Starpoints',
#  'Up to 50% Off'}

# %%
#After cleanup
set(data2['Price'])
# Out:
# {'$0.40',
#  '$0.60',
#  '$1',
#  '$1.25',
#  '$1.27',
#  '$1.60',
#  '$1.75',
#  '$10',
#  '$10 ',
#  '$100',
#  '$11',
#  '$11.65',
#  '$110',
#  '$1100',
#  '$12',
#  '$12.50',
#  '$12.75',
#  '$12.80',
#  '$13',
#  '$13.20',
#  '$138',
#  '$14',
#  '$144',
#  '$149',
#  '$15',
#  '$15.60',
#  '$159',
#  '$16',
#  '$16.80',
#  '$17',
#  '$18',
#  '$19',
#  '$2',
#  '$2.10',
#  '$2.40',
#  '$2.50',
#  '$20',
#  '$20.60',
#  '$200',
#  '$21.50',
#  '$23.50',
#  '$24',
#  '$270',
#  '$28',
#  '$29.50',
#  '$29.75',
#  '$299',
#  '$3',
#  '$3.14',
#  '$3.20',
#  '$3.90',
#  '$3.98',
#  '$30',
#  '$30.60',
#  '$300',
#  '$325',
#  '$35',
#  '$36',
#  '$362',
#  '$38',
#  '$4',
#  '$4.20',
#  '$4.55',
#  '$48',
#  '$49.50',
#  '$490',
#  '$495',
#  '$499',
#  '$5',
#  '$5.10',
#  '$5.60',
#  '$50',
#  '$51',
#  '$532',
#  '$54.90',
#  '$550',
#  '$569',
#  '$6.60',
#  '$6.75',
#  '$6.90',
#  '$60',
#  '$61',
#  '$660',
#  '$690',
#  '$7.50',
#  '$7.55',
#  '$700',
#  '$725',
#  '$750',
#  '$799',
#  '$8',
#  '$8.30',
#  '$8.35',
#  '$80',
#  '$800',
#  '$84',
#  '$88',
#  '$89',
#  '$9.50',
#  '$9.70',
#  '$9.75',
#  '$90',
#  '35% Off',
#  '50% Off',
#  '50K Points',
#  '80K Points',
#  'B1G1 Free',
#  'Free',
#  'Up to $300 Back',
#  'Up to 30% off',
#  'Up to 35K Starpoints',
#  'Up to 50% Off'}

# %%
NoDupsData = data.drop_duplicates()
NoDupsData2 = data2.drop_duplicates()

# %%
data2
# Out:
#                                          Extra Info  \
# 0                                       Terms Apply
# 1                                   + Free Shipping
# 2                                   + Free Shipping
# 3                                   + Free Shipping
# 4         More Options + Free Shipping and Handling
# 5                      + Free Shipping and Handling
# 6                       with $4K Spent in 1st 3-Mos
# 7              or Less + Free Shipping and Handling
# 8                                   + Free Shipping
# 9                                   + Free Shipping
# 10                                  + Free Shipping
# 11                      with $5K Spent in 1st 3-mos
# 12                      after $50 Slickdeals Rebate
# 13                        1% Cashback (Terms Apply)
# 14                        1% Cashback (Terms Apply)
# 15                                      Terms Apply
# 16                      with $4K Spent in 1st 3-Mos
# 17                                  + Free Shipping
# 18             + Free Shipping and Handling on $75+
# 19        More Options + Free Shipping and Handling
# 20                     + Free Shipping and Handling
# 21                                     with AutoPay
# 22                                    with Auto Pay
# 23                                  + Free Shipping
# 24                                  + Free Shipping
# 25                     More Options + Free Shipping
# 160  https://slickdeals.net/f/9795467-12-pack-oral-...
# 161  https://slickdeals.net/f/9845432-b-h-50-off-deals
# 162  https://slickdeals.net/f/9845348-4-pack-of-80-...
# 163  https://slickdeals.net/f/9845904-ps4-themes-ni...
# 164  https://slickdeals.net/f/9824615-playstation-p...
# 165  https://slickdeals.net/f/9839415-samsung-5-0-c...
# 166  https://slickdeals.net/f/9841215-contigo-autos...
# 167  https://slickdeals.net/f/9839939-xbox-one-arme...
# 168  https://slickdeals.net/f/9844095-4-months-of-g...
# 169  https://slickdeals.net/f/9841675-cafe-rio-bogo...
#
# [170 rows x 5 columns]

# %% [markdown]
# ###### 3. Merge dataframes from separate json files as appropriate
# - Find the intersection of two (or more) sets
# - Compare the intersection with the newer set to find 'New Products'
#     - When found, add the starting date
# - Compare the intersection with the older set to find 'Closed Products'
#     - When found, add the closing date
#     - Compare closing date with starting date to find days on market

# %%
# Create the inner merge of the two dataframes
dataInnerMerge = pd.merge(NoDupsData, NoDupsData2, \
                          on=['Extra Info','Item','Price','Retailer', 'Source'],\
                          how='inner')

# %%
# Determine the set of 'new products'
NoDupsData2['key1'] = 1
dataInnerMerge['key2'] = 1
newProducts = pd.merge(NoDupsData2, dataInnerMerge, \
                      on=['Extra Info', 'Item','Price','Retailer', 'Source'], \
                      how = 'left')

# Create the associated dataframe
newProducts = newProducts[newProducts.key2 != newProducts.key1]

# Add the starting date in the dataframe in which the product is first shown
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
# Determine the set of 'closed products'
NoDupsData['key1'] = 1
closedProducts = pd.merge(NoDupsData, dataInnerMerge, \
                      on=['Extra Info', 'Item','Price','Retailer', 'Source'], \
                      how = 'left')

# Create the associated dataframe
closedProducts = closedProducts[closedProducts.key2 != closedProducts.key1]

# Add the closing date in the dataframe in which the product is last shown


# Find days on market by comparing the starting date with the closing date

# %%
newProducts
# Out:
#                                          Extra Info  \
# 1                                   + Free Shipping
# 2                                   + Free Shipping
# 3                                   + Free Shipping
# 4         More Options + Free Shipping and Handling
# 5                      + Free Shipping and Handling
# 6                       with $4K Spent in 1st 3-Mos
# 7              or Less + Free Shipping and Handling
# 12                      after $50 Slickdeals Rebate
# 19        More Options + Free Shipping and Handling
# 20                     + Free Shipping and Handling
# 23                                  + Free Shipping
# 24                                  + Free Shipping
# 25                     More Options + Free Shipping
# 26                              + Free Store Pickup
# 27                              + Free Store Pickup
# 28                                 after $20 Rebate
# 29                                  + Free Shipping
# 30                                  + Free Shipping
# 31                                  + Free Shipping
# 32                                  + Free Shipping
# 33                 More Options + Free Store Pickup
# 35                              + Free Store Pickup
# 37        More Options + Free Shipping and Handling
# 38                             + Free Store Pick-Up
# 39    after $15 Rebate + Free Shipping and Handling
# 40                                     More Options
# 42                     + Free Shipping and Handling
# 44                     + Free Shipping and Handling
# 45                     + Free Shipping and Handling
# 46                           + Free In-Store Pickup
# ..                                              ...
# 137                                 + Free Shipping
# 140          More Options (Travel April, May & Jan)
# 141          More Options (Travel April, May & Jan)
# 142                                 + Free Shipping
# 143                    + Free Shipping and Handling
# 144                                 + Free Shipping
# 145                                 + Free Shipping
# 146                                    More Options
# 147                                    More Options
# 148                                 + Free Shipping
# 149                                after $30 Rebate
# 150  + Free Shipping and Handling for Prime Members
# 151                    + Free Shipping and Handling
# 152                                    More Options
# 153                                    More Options
# 154                                 + Free Shipping
# 155                             + Free Store Pickup
# 156                                 + Free Shipping
# 157                                 + Free Shipping
# 158                            (New Customers Only)
# 159                                 + Free Shipping
# 160            + Free Shipping and Handling on $49+
# 161            + Free Shipping and Handling on $49+
# 162            + Free Shipping and Handling on $49+
# 163                                    More Options
# 164                             + Free Store Pickup
# 165                             + Free Store Pickup
# 166                             + Free Store Pickup
# 167                               (New Subscribers)
# 168                                 (Select States)
#
#                                                   Item          Price  \
# 1    FreedomPop 3-In-1 LTE SIM Kit: Unl T&T + 2GB T...             $1
# 2    Canon imageCLASS MF249dw All-In-One Laser Printer           $149
# 3          Polk Audio LSi M704c Center Channel Speaker           $325
# 4    Charlotte Russe: Extra 20% Off Clearance: Beanies          $1.60
# 5    16oz. Mr. Coffee Pour! Brew! Go! Coffee Maker ...            $20
# 6                 Chase Sapphire Preferred Credit Card     50K Points
# 7     Dell XPS 8910 Desktop: i7-6700, 16GB DDR4, 750Ti           $690
# 12               22" Dell S2216H 1080p IPS LED Monitor            $60
# 19   $100 T-Mobile Prepaid Refill Card + HTC Desire...           $110
# 20                 200-Piece DEWALT Mechanics Tool Set            $89
# 23   Motorola Moto 360 2nd Gen Smartwatch (Refurbis...           $144
# 24                         TP-Link Networking Products  Up to 30% off
# 25   Macy's: 15% Off Beauty: $35 Estee Lauder Item ...         $29.75
# 26        Werner 2-Step 225-lb Steel Step Stool (Grey)            $12
# 27   Bare Necessities: Extra 30% Off Clearance: Nik...          $5.60
# 28    Corsair VS Series Power Supplies: 500W $21, 400W            $13
# 29          LEGO Classic XL Creative Brick Box (10654)            $51
# 30               $100 Lowes Gift Card (Email Delivery)            $90
# 31         HTC Vive VR Headset + RX 480 4GB Video Card           $799
# 32   3-Ct 16oz Philosophy 3-in-1 Shower Gels + 6-Pi...         $30.60
# 33   Macys VIP Sale: 32 Degrees Men's Crew-Neck T-S...          $4.20
# 35               Craftsman Compound Action Hedge Shear            $11
# 37   Home Storage: 30" Steel Shelving Unit (Chrome)...            $24
# 38       Global Shores Collection 16"x16" Mirror Clock          $6.75
# 39               Worldnect Dual Charging Stand for PS4           Free
# 40     $50 Newegg Digital Gift Card w/ $5 Promo Credit            $50
# 42                           Samsung Gear VR w/ Type C            $50
# 44   Zinus Upholstered Button Tufted Platform Bed: ...           $159
# 45   Add-On: Gillette Fusion Proshield Razor + 2 Re...          $5.60
# 46   Logitech MK570 Comfort Wave Wireless Keyboard/...            $35
# ..                                                 ...            ...
# 137  RAVPower 20100mAh Quick Charge 3.0 Portable Ba...            $36
# 140   Roundtrip Flight from Boston to New Delhi, India           $550
# 141  BESTEK 2-Socket Cigarette Lighter & 3.1A Dual ...          $7.50
# 142  2-Ct of .5oz Clinique Lotion + 3-Pc Skincare Gift            $10
# 143    Dell Inspiron 15 Laptop: i5-7300HQ, GTX 1050 Ti           $750
# 144       Prime w/ Alexa: Wink Hub 2 Smart Home Device            $80
# 145  Xiaomi Mi Band 2 Heart Rate Monitor Smart Brac...            $20
# 146  Choetech USB Type C Cables: 6-Pk Type C to Type C            $11
# 147  Forza Horizon 3 Duracell GTA Spano Car Pack DL...           Free
# 148  Martha Stewart Living Fabric Drawer (various c...          $3.20
# 149   MSI GeForce GTX 1080 8GB Video Card w/ Game Code           $490
# 150  ACDelco All Season Windshield Wiper Blade (var...          $1.27
# 151  GCU Members: The Legend of Zelda: Breath of th...            $48
# 152  Icon Packs (Android App): Karmanu, Timbul, Kas...           Free
# 153                   Syberia II (PC Digital Download)           Free
# 154  12-Pk 16.9oz Propel Zero Calorie Drinking Wate...          $5.10
# 155              2-Quart Crock-Pot Slow Cooker (Black)          $6.90
# 156  6-Pack of 16GB Emtec Car Key Style USB 2.0 Fla...         $12.50
# 157  Roundtrip Flight: San Francisco or LA to Austr...           $725
# 158     2-Years of Private Internet Access VPN Service            $51
# 159       12-Pack Oral-B Shiny Clean Soft Toothbrushes             $5
# 160  B&H Photo Video: Additional Savings on Select ...        50% Off
# 161  4-Pack of 80-Count Lysol Disinfecting Wipes (L...          $9.50
# 162  PS4 Themes: NieR: Automata Flight Unit Type-B ...           Free
# 163  PS+ Members: Disc Jam (PS4), Tearaway Unfolded...           Free
# 164  Samsung 5.0 cu. ft. Top Load Washer or 7.4 cu....           $660
# 165  Contigo Autoseal 16oz Insulated Stainless Stee...         $11.65
# 166  Walmart Stores: Xbox One SE Armed Forces Wirel...            $30
# 167  4-Months of Google Play Music/YouTube Red Subs...           Free
# 168  Cafe Rio Mexican Grill: Purchase Any Burrito o...      B1G1 Free
#
#                        Retailer  \
# 1                    FreedomPop
# 2                       Adorama
# 3                       Adorama
# 4               Charlotte Russe
# 5                    Mr. Coffee
# 6                         Chase
# 7                         Dell
# 12                        Dell
# 19                     T-Mobile
# 20                   Home Depot
# 23                          A4C
# 24                       Amazon
# 25                       Macy's
# 26                       Lowe's
# 27             Bare Necessities
# 28                       Newegg
# 29                    Toys R Us
# 30                         eBay
# 31                       Newegg
# 32                       Macy's
# 33                       Macy's
# 35                        Sears
# 37                   Home Depot
# 38                        Sears
# 39                       Newegg
# 40                      Groupon
# 42                     T-Mobile
# 44                       Amazon
# 45                       Amazon
# 46                     Best Buy
# ..                          ...
# 137                      Amazon
# 140                   Priceline
# 141                      Amazon
# 142                   Nordstrom
# 143                       Dell
# 144                      Amazon
# 145            Light In The Box
# 146                      Amazon
# 147             Microsoft Store
# 148  Home Decorators Collection
# 149                      Newegg
# 150                      Amazon
# 151                    Best Buy
# 152                 Google Play
# 153                   EA Origin
# 154                      Amazon
# 155                      Target
# 156                Daily Steals
# 157                     Expedia
# 158                 StackSocial
# 159                  iTechDeals
# 160             B&H Photo Video
# 161                      Amazon
# 162           Playstation Store
# 163           Playstation Store
# 164                       Sears
# 165                      Amazon
# 166                     Walmart
# 167                 Google Play
# 168      Cafe Rio Mexican Grill
#
#                                                 Source  key1  key2
# 1    https://slickdeals.net/f/9841799-0-99-free-tal...     1   NaN
# 2    https://slickdeals.net/f/9707596-canon-imagecl...     1   NaN
# 3    https://slickdeals.net/f/9829687-polk-audio-ls...     1   NaN
# 156  https://slickdeals.net/f/9821179-6-pack-of-16g...     1   NaN
# 157  https://slickdeals.net/f/9846204-roundtrip-fli...     1   NaN
# 158  https://slickdeals.net/f/9843455-2-years-of-pr...     1   NaN
# 159  https://slickdeals.net/f/9795467-12-pack-oral-...     1   NaN
# 160  https://slickdeals.net/f/9845432-b-h-50-off-deals     1   NaN
# 161  https://slickdeals.net/f/9845348-4-pack-of-80-...     1   NaN
# 162  https://slickdeals.net/f/9845904-ps4-themes-ni...     1   NaN
# 163  https://slickdeals.net/f/9824615-playstation-p...     1   NaN
# 164  https://slickdeals.net/f/9839415-samsung-5-0-c...     1   NaN
# 165  https://slickdeals.net/f/9841215-contigo-autos...     1   NaN
# 166  https://slickdeals.net/f/9839939-xbox-one-arme...     1   NaN
# 167  https://slickdeals.net/f/9844095-4-months-of-g...     1   NaN
# 168  https://slickdeals.net/f/9841675-cafe-rio-bogo...     1   NaN
#
# [123 rows x 7 columns]

# %%
len(newProducts)
# Out:
# 123

# %% [markdown]
# ###### 4. Create visualizations
# - Histogram of Prices
# - Histogram of Days on Market
# - Scatter Diagram of Prices vs Days on Market
# - Pie Chart of New, Like New, Used

# %%
# Create a histogram of Prices
goodPrices = newProducts.Price[newProducts['Price'] > 1.0]
goodPrices = goodPrices[goodPrices < 1500.0]
plt.hist(goodPrices)
plt.title("Product Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

#Temporary Data for Days on Market ... for Scatter Plot Example
scatterData = {'Price': goodPrices,\
               'daysOnMarket' : \
               np.random.randint(1,30,size=len(goodPrices))}
sD = pd.DataFrame(scatterData)

# Create a histogram of Days on Market
plt.hist(sD.daysOnMarket)
plt.title("Days On Market")
plt.xlabel("Days")
plt.ylabel("Frequency")
plt.show()

# Create a Scatter Diagram of Prices vs Days on Market
fig = plt.figure()
ax = fig.add_subplot(111)
x = sD.Price
y = sD.daysOnMarket
ax.scatter(x,y,color='blue')
ax.set_ylim([0,30])
ax.set_xlim([0,1600])

plt.title("Days On Market vs Price")
plt.xlabel("Price")
plt.ylabel("Days On Market")
plt.show()

# Create a Pie Chart of New, Like New, and Used products
colors = ["#E13F29", "#D69A80", "#D63B59"]
# Create a pie chart
plt.pie(
    [newProducts.Condition[newProducts.Condition == 'like new'].count(),\
     newProducts.Condition[newProducts.Condition == 'new'].count(), \
     newProducts.Condition[newProducts.Condition == 'used'].count()],
    labels= ['like_new','new','used'],
    shadow=True,
    # with colors
    colors=colors,
    # with one slide exploded out
    explode=(0.1, 0, 0),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%1.1f%%',
    )

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-180-ae5ec117f7d5> in <module>()
#       1 # Create a histogram of Prices
# ----> 2 goodPrices = newProducts.Price[newProducts['Price'] > 1.0]
#       3 goodPrices = goodPrices[goodPrices < 1500.0]
#       4 plt.hist(goodPrices)
#       5 plt.title("Product Prices")
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     761                 other = np.asarray(other)
#     762
# --> 763             res = na_op(values, other)
#     764             if isscalar(res):
#     765                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     681                     result = lib.vec_compare(x, y, op)
#     682             else:
# --> 683                 result = lib.scalar_compare(x, y, op)
#     684         else:
#     685
#
# pandas\lib.pyx in pandas.lib.scalar_compare (pandas\lib.c:14261)()
#
# TypeError: unorderable types: str() > float()

# %% [markdown]
# ###### 5. Trends from your data
# - Search for specific brands and offer counts for each
# - Search for product types and offer counts for each
# - For each of the above (and other) give counts for day over day or week over week

# %%
set(data2.Price)
# Out:
# {'$0.40',
#  '$0.60',
#  '$1',
#  '$1.25',
#  '$1.27',
#  '$1.60',
#  '$1.75',
#  '$10',
#  '$10 ',
#  '$100',
#  '$11',
#  '$11.65',
#  '$110',
#  '$1100',
#  '$12',
#  '$12.50',
#  '$12.75',
#  '$12.80',
#  '$13',
#  '$13.20',
#  '$138',
#  '$14',
#  '$144',
#  '$149',
#  '$15',
#  '$15.60',
#  '$159',
#  '$16',
#  '$16.80',
#  '$17',
#  '$18',
#  '$19',
#  '$2',
#  '$2.10',
#  '$2.40',
#  '$2.50',
#  '$20',
#  '$20.60',
#  '$200',
#  '$21.50',
#  '$23.50',
#  '$24',
#  '$270',
#  '$28',
#  '$29.50',
#  '$29.75',
#  '$299',
#  '$3',
#  '$3.14',
#  '$3.20',
#  '$3.90',
#  '$3.98',
#  '$30',
#  '$30.60',
#  '$300',
#  '$325',
#  '$35',
#  '$36',
#  '$362',
#  '$38',
#  '$4',
#  '$4.20',
#  '$4.55',
#  '$48',
#  '$49.50',
#  '$490',
#  '$495',
#  '$499',
#  '$5',
#  '$5.10',
#  '$5.60',
#  '$50',
#  '$51',
#  '$532',
#  '$54.90',
#  '$550',
#  '$569',
#  '$6.60',
#  '$6.75',
#  '$6.90',
#  '$60',
#  '$61',
#  '$660',
#  '$690',
#  '$7.50',
#  '$7.55',
#  '$700',
#  '$725',
#  '$750',
#  '$799',
#  '$8',
#  '$8.30',
#  '$8.35',
#  '$80',
#  '$800',
#  '$84',
#  '$88',
#  '$89',
#  '$9.50',
#  '$9.70',
#  '$9.75',
#  '$90',
#  '35% Off',
#  '50% Off',
#  '50K Points',
#  '80K Points',
#  'B1G1 Free',
#  'Free',
#  'Up to $300 Back',
#  'Up to 30% off',
#  'Up to 35K Starpoints',
#  'Up to 50% Off'}

# %%
dollarData = NoDupsData[NoDupsData['Price'].str.contains("\$")]
dollarData2 = NoDupsData2[NoDupsData2['Price'].str.contains('\$')]

#retailerData = NoDupsData[NoDupsData['Retailer']]
#retailerData2 = NoDupsData2[NoDupsData2['Retailer']]

# %%
dollarData
# Out:
#                                           Extra Info  \
# 2          More Options + Free Shipping and Handling
# 4                                    + Free Shipping
# 5                               (New Customers Only)
# 6                   More Options + Free Store Pickup
# 7                   More Options + Free Store Pickup
# 8                   More Options + Free Store Pickup
# 9                                    + Free Shipping
# 10                      More Options + Free Shipping
# 11                      More Options + Free Shipping
# 12                      More Options + Free Shipping
# 13                                   + Free Shipping
# 14                                   + Free Shipping
# 15                                   + Free Shipping
# 17                       with $5K Spent in 1st 3-mos
# 18                         1% Cashback (Terms Apply)
# 19                         1% Cashback (Terms Apply)
# 33   28" Dell S2817QR 4K Ultra HD LED Monitor w/ Fr...             $300
# 35                     Xbox One Chatpad + Chat Headset           $22.50
# 36   4' Motion Activated Flexible LED Light Strip w...            $6.80
# 37        65" LG 65UH9500 3D 4K UHD HDR Smart LED HDTV            $1497
# ..                                                 ...              ...
# 150                   The Giving Tree (Hardcover Book)            $8.30
# 151  ARRIS SURFboard SB6141 DOCSIS 3.0 Cable Modem ...           $21.50
# 152                                 Battlefield 4 (PC)               $3
# 153         BenQ W1070 1080p 3D Home Theater Projector             $499
# 154  32GB Samsung Galaxy S7 Edge (AT&T) + 128GB mic...             $495
# 155      Prime Family: Huggies Pull Ups Training Pants           $13.20
# 156   208-Piece Craftsman Ultimate Screwdriver Bit Set              $20
# 157  H&R Block Tax Software: Deluxe + State 2016 $2...              $15
# 158           PSN Sale: Shin Megami Tensei Games (PS3)               $5
# 159  GCU Members: World of Final Fantasy (PS4) $24,...              $12
# 160  GCU Members: Titanfall 2 Deluxe Edition (PS4 o...              $20
# 161  Roundtrip Flight from Seattle to Kailua Kona, ...             $362
# 162  Roundtrip Flight: Los Angeles or San Diego to ...             $532
# 163                                    Watch Dogs (PC)               $3
# 164               FoodSaver 2.25-Quart Quick Marinator              $12
# 165     24-Pack Acoustic Panels Foam Wedges 1"X12"X12"              $28
# 166  Papa John's: Free Large 3-Topping Pizza (Futur...              $15
# 167  Red Pocket Mobile: Essentials Plan (500 Min., ...             $10
# 169            adidas Men's Galaxy Elite Running Shoes              $30
# 170           Sharper Image Men's Memory Foam Slippers            $3.90
# 171  Prime w/ Alexa: Reorder Any Item ($5+) from Pu...               $5
# 173  Digital HD Rentals: Hachi: A Dog's Tale or Mem...               $1
# 174  TorGuard 50% Off VPN Service: $30/year, Proxy ...           $23.50
# 178  Cellucor C4 50X Pre-Workout Supplement (45-Ser...              $15
# 181                   Aden + Anais: Toddler Bed in Bag           $49.50
# 182  Select Walmart Stores: Bike Clearance: Men's &...              $17
# 183  Daniel Tiger's Neighborhood Board Books (Various)            $2.50
# 185  RAVPower 20100mAh Quick Charge 3.0 Portable Ba...              $36
# 186  16GB (2x8GB) Avexir Core Series DDR4 Desktop M...              $80
# 187  Walmart Stores: 2-Piece Sheffield Precision To...            $1.25
#
#                        Retailer  \
# 2                       Adorama
# 4                       Adorama
# 5                        TaxAct
# 6                        Macy's
# 7                        Amazon
# 8                         Dell
# 9                           REI
# 10                       Macy's
# 11                       Macy's
# 12                        Dell
# 13                      Walmart
# 14                        Dell
# 15                     Best Buy
# 17                        Dell
# 18                         Amex
# 19                        Chase
# 22                   FreedomPop
# 24                     T-Mobile
# 25                   Home Depot
# 26                     T-Mobile
# 27             Verizon Wireless
# 28                     Fidelity
# 29                         eBay
# 30                     Best Buy
# 31                       Amazon
# 32                      Adorama
# 33   Office Depot and OfficeMax
# 35                      Walmart
# 36                   AliExpress
# 37                       BuyDig
# ..                          ...
# 150                      Amazon
# 151                      Amazon
# 152                    GameStop
# 153                    Best Buy
# 154                     Samsung
# 155                      Amazon
# 156                       Sears
# 144    Dell Inspiron 15 Laptop: i5-7300HQ, GTX 1050 Ti             $750
# 145       Prime w/ Alexa: Wink Hub 2 Smart Home Device              $80
# 146  Xiaomi Mi Band 2 Heart Rate Monitor Smart Brac...              $20
# 147  Choetech USB Type C Cables: 6-Pk Type C to Type C              $11
# 149  Martha Stewart Living Fabric Drawer (various c...            $3.20
# 150   MSI GeForce GTX 1080 8GB Video Card w/ Game Code             $490
# 151  ACDelco All Season Windshield Wiper Blade (var...            $1.27
# 152  GCU Members: The Legend of Zelda: Breath of th...              $48
# 155  12-Pk 16.9oz Propel Zero Calorie Drinking Wate...            $5.10
# 156              2-Quart Crock-Pot Slow Cooker (Black)            $6.90
# 157  6-Pack of 16GB Emtec Car Key Style USB 2.0 Fla...           $12.50
# 158  Roundtrip Flight: San Francisco or LA to Austr...             $725
# 159     2-Years of Private Internet Access VPN Service              $51
# 160       12-Pack Oral-B Shiny Clean Soft Toothbrushes               $5
# 162  4-Pack of 80-Count Lysol Disinfecting Wipes (L...            $9.50
# 165  Samsung 5.0 cu. ft. Top Load Washer or 7.4 cu....             $660
# 166  Contigo Autoseal 16oz Insulated Stainless Stee...           $11.65
# 167  Walmart Stores: Xbox One SE Armed Forces Wirel...              $30
#
#                        Retailer  \
# 1                    FreedomPop
# 2                       Adorama
# 3                       Adorama
# 4               Charlotte Russe
# 5                    Mr. Coffee
# 7                         Dell
# 8                       Walmart
# 9                         Dell
# 10                     Best Buy
# 12                        Dell
# 13                         Amex
# 14                        Chase
# 17                   FreedomPop
# 19                     T-Mobile
# 20                   Home Depot
# 21                     T-Mobile
# 22             Verizon Wireless
# 23                          A4C
# 25                       Macy's
# 26                       Lowe's
# 27             Bare Necessities
# 28                       Newegg
# 29                    Toys R Us
# 30                         eBay
# 31                       Newegg
# 32                       Macy's
# 33                       Macy's
# 34                       Amazon
# 35                        Sears
# 36                       Amazon
# ..                          ...
# 126                    TorGuard
# 130                    Best Buy
# 131                    Cellucor
# 134                      Amazon
# 135              Walmart Stores
# 136                      Amazon
# 138                      Amazon
# 139                      Amazon
# 140                     Walmart
# 141                   Priceline
# 142                      Amazon
# 143                   Nordstrom
# 144                       Dell
# 145                      Amazon
# 146            Light In The Box
# 147                      Amazon
# 149  Home Decorators Collection
# 150                      Newegg
# 151                      Amazon
# 152                    Best Buy
# 155                      Amazon
# 156                      Target
# 157                Daily Steals
# 158                     Expedia
# 159                 StackSocial
# 160                  iTechDeals
# 162                      Amazon
# 165                       Sears
# 166                      Amazon
# 167                     Walmart
#
#                                                 Source  key1
# 1    https://slickdeals.net/f/9841799-0-99-free-tal...     1
# 2    https://slickdeals.net/f/9707596-canon-imagecl...     1
# 3    https://slickdeals.net/f/9829687-polk-audio-ls...     1
# 4    https://slickdeals.net/f/9841779-charlotte-rus...     1
# 5    https://slickdeals.net/f/9842015-16oz-mr-coffe...     1
# 7    https://slickdeals.net/f/9866324-dell-xps-8910...     1
# 8    https://slickdeals.net/f/9853316-dell-inspiron...     1
# 9    https://slickdeals.net/f/9862304-55-samsung-un...     1
# 162  https://slickdeals.net/f/9845348-4-pack-of-80-...     1
# 165  https://slickdeals.net/f/9839415-samsung-5-0-c...     1
# 166  https://slickdeals.net/f/9841215-contigo-autos...     1
# 167  https://slickdeals.net/f/9839939-xbox-one-arme...     1
#
# [141 rows x 6 columns]

# %%
# List the products representing specific brands of your choosing
# for each date provided
fenderData = NoDupsData[NoDupsData['Title'].str.contains('fender ')]
yamahaData = NoDupsData[NoDupsData['Title'].str.contains('yamaha ')]
gibsonData = NoDupsData[NoDupsData['Title'].str.contains('gibson ')]
fenderData2 = NoDupsData2[NoDupsData2['Title'].str.contains('fender ')]
yamahaData2 = NoDupsData2[NoDupsData2['Title'].str.contains('yamaha ')]
gibsonData2 = NoDupsData2[NoDupsData2['Title'].str.contains('gibson ')]

# Create a bar chart of products by brand (for the brands chosen)
fenderCount = len(fenderData)
yamahaCount = len(yamahaData)
gibsonCount = len(gibsonData)
fenderCount2 = len(fenderData2)
yamahaCount2 = len(yamahaData2)
gibsonCount2 = len(gibsonData2)

objects = ('Fender','Fender2','', 'Yamaha', 'Yamaha2','', \
           'Gibson', 'Gibson2')
colors = ('green','red','blue','green','red','blue','green','red')
y_pos = np.arange(len(objects))
performance = [fenderCount,fenderCount2,0,yamahaCount,yamahaCount2,\
               0,gibsonCount,gibsonCount2]
fig = plt.figure(figsize=(15,7))
plt.bar(y_pos, performance, align='center',alpha=0.5, color=colors)
plt.xticks(y_pos, objects)
plt.ylabel('Counts')
plt.title('Brands')
 
plt.show()

# List the products of a specific type
guitarData = NoDupsData[NoDupsData['Title'].str.contains('guitar ')]
audioData = NoDupsData[NoDupsData['Title'].str.contains('audio ')]
drumData = NoDupsData[NoDupsData['Title'].str.contains('drum ')]
guitarData2 = NoDupsData2[NoDupsData2['Title'].str.contains('guitar ')]
audioData2 = NoDupsData2[NoDupsData2['Title'].str.contains('audio ')]
drumData2 = NoDupsData2[NoDupsData2['Title'].str.contains('drum ')]


# Create a bar chart of products by specific type
# for each date provided
guitarCount = len(guitarData)
audioCount = len(audioData)
drumCount = len(drumData)
guitarCount2 = len(guitarData2)
audioCount2 = len(audioData2)
drumCount2 = len(drumData2)

objects = ('Guitar','Guitar2','', 'Audio','Audio2','', 'Drum','Drum2')
y_pos = np.arange(len(objects))
performance = [guitarCount,guitarCount2,0,audioCount,audioCount2,\
               0,drumCount,drumCount2]
colors = ('green','red','blue','green','red','blue','green','red') 
plt.bar(y_pos, performance, align='center', alpha=0.5, color=colors)
plt.xticks(y_pos, objects)
plt.ylabel('Counts')
plt.title('Product Type')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'Title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-185-4974aebe6128> in <module>()
#       1 # List the products representing specific brands of your choosing
#       2 # for each date provided
# ----> 3 fenderData = NoDupsData[NoDupsData['Title'].str.contains('fender ')]
#       4 yamahaData = NoDupsData[NoDupsData['Title'].str.contains('yamaha ')]
#       5 gibsonData = NoDupsData[NoDupsData['Title'].str.contains('gibson ')]
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'Title'

# %%
fenderData[['Link','Title']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-186-185ac205f340> in <module>()
# ----> 1 fenderData[['Link','Title']]
#
# NameError: name 'fenderData' is not defined

# %%
drumData[['Link','Title']]
