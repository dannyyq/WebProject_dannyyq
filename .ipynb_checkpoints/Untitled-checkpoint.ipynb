# %%
import pandas as pd

filename = '2017-02-21.SDNewsBriefs.json'

data = pd.read_json(filename)

# %%
data
# Out:
#                                                   Item  \
# 0                Starwood Preferred Guest® Credit Card
# 1    Sony Camera & Lens Trade-in: Trade in DSLR, Mi...
# 2                    Chase Ink Business Preferred Card
# 3           US Mattress Sale: Simmons Beautyrest Queen
# 4          Nucleus Anywhere Intercom with Amazon Alexa
# 5                 Chase Sapphire Preferred Credit Card
# 6    64" MeFOTO GlobeTrotter Carbon Fiber Tripod w/...
# 7    Rheem Hybrid Electric Water Heater: 80-Gal $15...
# 8                Starwood Preferred Guest® Credit Card
# 9                 Chase Sapphire Preferred Credit Card
# 10   Slate® by Chase Intro Offer: 0% APR for 15 Mon...
# 11   T-Mobile One Unlimited Plan: 2-Lines (Data/Tal...
# 12                   Chase Ink Business Preferred Card
# 13   Verizon: Unlimited Everything Plan (Data/Talk/...
# 14                   T-fal 12-Quart Nonstick Stock Pot
# 15   Patagonia Clothing Sale: Shirts, Jackets, Hood...
# ...

# %%
data.Item
# Out:
# 0                  Starwood Preferred Guest® Credit Card
# 1      Sony Camera & Lens Trade-in: Trade in DSLR, Mi...
# 2                      Chase Ink Business Preferred Card
# 3             US Mattress Sale: Simmons Beautyrest Queen
# 4            Nucleus Anywhere Intercom with Amazon Alexa
# 5                   Chase Sapphire Preferred Credit Card
# 6      64" MeFOTO GlobeTrotter Carbon Fiber Tripod w/...
# 7      Rheem Hybrid Electric Water Heater: 80-Gal $15...
# 8                  Starwood Preferred Guest® Credit Card
# 9                   Chase Sapphire Preferred Credit Card
# 10     Slate® by Chase Intro Offer: 0% APR for 15 Mon...
# 11     T-Mobile One Unlimited Plan: 2-Lines (Data/Tal...
# 12                     Chase Ink Business Preferred Card
# 13     Verizon: Unlimited Everything Plan (Data/Talk/...
# 14                     T-fal 12-Quart Nonstick Stock Pot
# 15     Patagonia Clothing Sale: Shirts, Jackets, Hood...
# ...

# %%
data['Item']
# Out:
# 0                  Starwood Preferred Guest® Credit Card
# 1      Sony Camera & Lens Trade-in: Trade in DSLR, Mi...
# 2                      Chase Ink Business Preferred Card
# 3             US Mattress Sale: Simmons Beautyrest Queen
# 4            Nucleus Anywhere Intercom with Amazon Alexa
# 5                   Chase Sapphire Preferred Credit Card
# 6      64" MeFOTO GlobeTrotter Carbon Fiber Tripod w/...
# 7      Rheem Hybrid Electric Water Heater: 80-Gal $15...
# 8                  Starwood Preferred Guest® Credit Card
# 9                   Chase Sapphire Preferred Credit Card
# 10     Slate® by Chase Intro Offer: 0% APR for 15 Mon...
# 11     T-Mobile One Unlimited Plan: 2-Lines (Data/Tal...
# 12                     Chase Ink Business Preferred Card
# 13     Verizon: Unlimited Everything Plan (Data/Talk/...
# 14                     T-fal 12-Quart Nonstick Stock Pot
# 15     Patagonia Clothing Sale: Shirts, Jackets, Hood...
# ...

# %%
i = 0
for stuff in data.Retailer:
    if('Amazon') in stuff:
        print(stuff)
        print()
        i += 1
print(i)
# Out:
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# Amazon
#
# 21

# %%
data.sort_values('Retailer')
# Out:
#                                                   Item  \
# 6    64" MeFOTO GlobeTrotter Carbon Fiber Tripod w/...
# 34        12-Month Amazon Drive Unlimited Storage Plan
# 45   Prime Members: Amazon Dash Button + $4.99 Cred...
# 101  Prime Members: Kendrick Lamar Good Kid Madd Ci...
# 103  Aukey QC 3.0 Chargers: 2-Ports Wall Charger $1...
# 24                           Dyson Tangle Free Turbine
# 52     Prime Deal: 6-Pk of 1-Qt Mobil 1 Syn. Motor Oil
# 25   Monster Hunter 4 Ultimate Standard Edition (Ni...
# 26        Digital HD Movies: The BFG, Tank Girl & More
# 61   Fujifilm Instax Mini 8 Camera (Black) + 20-She...
# 28   80-Ct San Francisco Bay OneCup Single Serve K-...
# 64   Prime Members: 24-Pk San Pellegrino Sparkling ...
# 92   Milanese Loop Stainless Steel Band for Apple W...
# 31   Digital HD Rentals: Florence Foster Jenkins or...
# 106  The 5 Elements of Om Mani Padme Hum (MP3 Album...
# 69   Brother Printer MFC-L8850CDW Wireless Color La...
# ...

# %%
data.sort_values(['Retailer','Price'], ascending=[True,False])
# Out:
#                                                   Item  \
# 6    64" MeFOTO GlobeTrotter Carbon Fiber Tripod w/...
# 111      12-Count of 1.4oz Kind Bars (various flavors)
# 82   Planet Earth II: Season 1: Islands (HD Digital...
# 106  The 5 Elements of Om Mani Padme Hum (MP3 Album...
# 4          Nucleus Anywhere Intercom with Amazon Alexa
# 92   Milanese Loop Stainless Steel Band for Apple W...
# 103  Aukey QC 3.0 Chargers: 2-Ports Wall Charger $1...
# 34        12-Month Amazon Drive Unlimited Storage Plan
# 61   Fujifilm Instax Mini 8 Camera (Black) + 20-She...
# 24                           Dyson Tangle Free Turbine
# 26        Digital HD Movies: The BFG, Tank Girl & More
# 69   Brother Printer MFC-L8850CDW Wireless Color La...
# 52     Prime Deal: 6-Pk of 1-Qt Mobil 1 Syn. Motor Oil
# 28   80-Ct San Francisco Bay OneCup Single Serve K-...
# 45   Prime Members: Amazon Dash Button + $4.99 Cred...
# 25   Monster Hunter 4 Ultimate Standard Edition (Ni...
# ...

# %%
data[data['Retailer'] == 'Amazon']
# Out:
#                                                   Item  \
# 4          Nucleus Anywhere Intercom with Amazon Alexa
# 20   Aukey Wireless Bluetooth 4.1 Sports Headphones...
# 24                           Dyson Tangle Free Turbine
# 25   Monster Hunter 4 Ultimate Standard Edition (Ni...
# 26        Digital HD Movies: The BFG, Tank Girl & More
# 28   80-Ct San Francisco Bay OneCup Single Serve K-...
# 31   Digital HD Rentals: Florence Foster Jenkins or...
# 34        12-Month Amazon Drive Unlimited Storage Plan
# 45   Prime Members: Amazon Dash Button + $4.99 Cred...
# 52     Prime Deal: 6-Pk of 1-Qt Mobil 1 Syn. Motor Oil
# 61   Fujifilm Instax Mini 8 Camera (Black) + 20-She...
# 64   Prime Members: 24-Pk San Pellegrino Sparkling ...
# 69   Brother Printer MFC-L8850CDW Wireless Color La...
# 81   Prime Members: Bob Marley & The Wailers Legend...
# 82   Planet Earth II: Season 1: Islands (HD Digital...
# 86   2-lb Orgain Organic Protein Plant-Based Powder...
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data['Retailer'].value_counts().plot.bar(figsize = (10,6))
plt.show()

# %%
data['Price'].value_counts().plot.bar(figsize = (10,6))
plt.show()
